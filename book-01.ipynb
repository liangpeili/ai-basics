# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np 
a = np.array([0, 1, 2, 3, 4, 5])
print(a)
# Out:
# [0 1 2 3 4 5]

# %%
import numpy as np
import matplotlib.pyplot as plt 

x = np.linspace(-5, 5)
y = 2 * x

plt.plot(x, y)
plt.show()

# %% [markdown]
# # 题目1
